# %%
from abc import ABC,abstractmethod

# %%
import abc

class grandparent():
    @abstractmethod
    def properties(self):
        print("this is grandparent class property")
    
    @abstractmethod
    def gold(self):
        print("this is grandparent class gold")
        
        abstractclassmethod
    
class parent(ABC,grandparent):
    @abstractmethod
    def properties(self):
        print("this is parent class property")
    
    @abstractmethod
    def gold(self):
        print("this is parent class gold")

class child(parent):
    @abstractmethod
    def properties(self):
        print("this is child class property")
        
c = child()
c.properties()
c.gold()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 26
#      22     @abstractmethod
#      23     def properties(self):
#      24         print("this is child class property")
# ---> 26 c = child()
#      27 c.properties()
#      28 c.gold()
#
# TypeError: Can't instantiate abstract class child with abstract methods gold, properties

# %%
help(abc)
# Out:
# Help on module abc:
#
# NAME
#     abc - Abstract Base Classes (ABCs) according to PEP 3119.
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/abc.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# CLASSES
#     builtins.classmethod(builtins.object)
#         abstractclassmethod
#     builtins.object
#         ABC
#     builtins.property(builtins.object)
#         abstractproperty
#     builtins.staticmethod(builtins.object)
#         abstractstaticmethod
#     builtins.type(builtins.object)
#         ABCMeta
#
#     class ABC(builtins.object)
#      |  Helper class that provides a standard way to create an ABC using
#      |  inheritance.
#      |
# ...

# %%
dir(abc)
# Out:
# ['ABC',
#  'ABCMeta',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_abc_init',
#  '_abc_instancecheck',
#  '_abc_register',
#  '_abc_subclasscheck',
#  '_get_dump',
#  '_reset_caches',
#  '_reset_registry',
#  'abstractclassmethod',
#  'abstractmethod',
#  'abstractproperty',
#  'abstractstaticmethod',
#  'get_cache_token',
#  'update_abstractmethods']
