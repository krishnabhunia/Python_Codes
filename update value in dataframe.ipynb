# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\kbhunia\Downloads\GDrive Backup Downloads\Jupyter Notebook Programs\excel read files\Sample Data Safety.csv")
df
# Out:
#           Date Injury Location  Gender Age Group   Incident Type  Days Lost  \
# 0     1-Jan-20        Multiple    Male     25-34            Burn        0.0
# 1     3-Jan-20             NaN    Male     35-49         Vehicle        0.5
# 2     3-Jan-20             Eye    Male     18-24             Cut        0.0
# 3     4-Jan-20            Legs  Female       50+  Falling object        0.0
# 4     7-Jan-20            Legs    Male     25-34         Lifting        0.0
# ..         ...             ...     ...       ...             ...        ...
# 509  26-Jun-22            Head  Female     25-34   Crush & Pinch        0.0
# 510  27-Jun-22           Hands    Male     25-34         Lifting        0.0
# 511  28-Jun-22           Hands    Male     25-34             Cut        0.0
# 512  28-Jun-22           Trunk    Male       50+  Falling object        0.0
# 513  28-Jun-22           Hands    Male     18-24         Vehicle        0.0
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#        Date Injury Location  Gender Age Group   Incident Type  Days Lost  \
# 0  1-Jan-20        Multiple    Male     25-34            Burn        0.0
# 1  3-Jan-20             NaN    Male     35-49         Vehicle        0.5
# 2  3-Jan-20             Eye    Male     18-24             Cut        0.0
# 3  4-Jan-20            Legs  Female       50+  Falling object        0.0
# 4  7-Jan-20            Legs    Male     25-34         Lifting        0.0
#
#      Plant Report Type      Shift      Department Incident Cost WkDay  Month  \
# 0     Iowa   Near Miss  Afternoon        Painting           $0    Wed      1
# 1  Alabama   Lost Time        Day     Fabrication       $3,367    Fri      1
# 2  Georgia   Near Miss        Day  Administration           $0    Fri      1
# 3     Iowa   Near Miss        Day        Painting           $0    Sat      1
# 4     Ohio   Near Miss        Day        Painting           $0    Tue      1
#
#    Year
# 0  2020
# 1  2020
# 2  2020
# 3  2020
# 4  2020

# %%
df[df["Year"]==2020]
# Out:
#           Date Injury Location  Gender Age Group   Incident Type  Days Lost  \
# 0     1-Jan-20        Multiple    Male     25-34            Burn        0.0
# 1     3-Jan-20             NaN    Male     35-49         Vehicle        0.5
# 2     3-Jan-20             Eye    Male     18-24             Cut        0.0
# 3     4-Jan-20            Legs  Female       50+  Falling object        0.0
# 4     7-Jan-20            Legs    Male     25-34         Lifting        0.0
# ..         ...             ...     ...       ...             ...        ...
# 216  27-Dec-20             Eye    Male     25-34  Falling object        0.0
# 217  27-Dec-20            Legs    Male     25-34            Burn        0.0
# 218  30-Dec-20           Trunk    Male       50+            Burn        0.0
# 219  30-Dec-20           Trunk    Male     18-24            Fall        0.0
# 220  31-Dec-20         Abdomen    Male     25-34            Burn        2.0
#
# ...

# %%
df.isnull()
# Out:
#       Date  Injury Location  Gender  Age Group  Incident Type  Days Lost  \
# 0    False            False   False      False          False      False
# 1    False             True   False      False          False      False
# 2    False            False   False      False          False      False
# 3    False            False   False      False          False      False
# 4    False            False   False      False          False      False
# ..     ...              ...     ...        ...            ...        ...
# 509  False            False   False      False          False      False
# 510  False            False   False      False          False      False
# 511  False            False   False      False          False      False
# 512  False            False   False      False          False      False
# 513  False            False   False      False          False      False
#
#      Plant  Report Type  Shift  Department  Incident Cost  WkDay  Month   Year
# ...

# %%
df.isnull().sum()
# Out:
# Date                0
# Injury Location    42
# Gender              0
# Age Group           0
# Incident Type       0
# Days Lost           0
# Plant               0
# Report Type         0
# Shift               0
# Department          0
# Incident Cost       0
# WkDay               0
# Month               0
# Year                0
# dtype: int64

# %%
df.loc[3:7,{"Date","Injury Location","Year"}]
# Out:
# C:\Users\kbhunia\AppData\Local\Temp\ipykernel_25464\1323512253.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df.loc[3:7,{"Date","Injury Location","Year"}]
#         Date Injury Location  Year
# 3   4-Jan-20            Legs  2020
# 4   7-Jan-20            Legs  2020
# 5  11-Jan-20             NaN  2020
# 6  11-Jan-20            Neck  2020
# 7  12-Jan-20            Feet  2020

# %%
df.loc[3:7,["Date","Injury Location","Year"]]
# Out:
#         Date Injury Location  Year
# 3   4-Jan-20            Legs  2020
# 4   7-Jan-20            Legs  2020
# 5  11-Jan-20             NaN  2020
# 6  11-Jan-20            Neck  2020
# 7  12-Jan-20            Feet  2020

# %%
df[df["Injury Location"]=="Eye"]
# Out:
#           Date Injury Location  Gender Age Group   Incident Type  Days Lost  \
# 2     3-Jan-20             Eye    Male     18-24             Cut        0.0
# 12   26-Jan-20             Eye    Male     35-49         Vehicle        0.0
# 13   27-Jan-20             Eye    Male       50+            Burn        0.0
# 14   27-Jan-20             Eye    Male     35-49            Burn        0.0
# 38    3-Mar-20             Eye    Male     35-49            Burn        0.0
# 40    6-Mar-20             Eye    Male     25-34            Burn        0.0
# 46   20-Mar-20             Eye    Male     35-49         Lifting        0.0
# 56   13-Apr-20             Eye  Female       50+         Vehicle        4.5
# 61   16-Apr-20             Eye    Male       50+            Burn        0.0
# 69   25-Apr-20             Eye  Female       50+       Equipment        0.0
# 77    9-May-20             Eye    Male     35-49            Fall        0.0
# ...

# %%
df.loc[3:7,:]
# Out:
#         Date Injury Location  Gender Age Group   Incident Type  Days Lost  \
# 3   4-Jan-20            Legs  Female       50+  Falling object        0.0
# 4   7-Jan-20            Legs    Male     25-34         Lifting        0.0
# 5  11-Jan-20             NaN  Female       50+   Crush & Pinch        0.0
# 6  11-Jan-20            Neck    Male     25-34   Crush & Pinch        3.5
# 7  12-Jan-20            Feet    Male     35-49            Burn        1.5
#
#         Plant Report Type      Shift      Department Incident Cost WkDay  \
# 3        Iowa   Near Miss        Day        Painting           $0    Sat
# 4        Ohio   Near Miss        Day        Painting           $0    Tue
# 5     Georgia   First Aid  Afternoon        Security         $132    Sat
# 6        Iowa   Lost Time        Day      Purchasing       $4,872    Sat
# 7  California   Lost Time      Night  Administration       $1,248    Sun
#
#    Month  Year
# 3      1  2020
# 4      1  2020
# 5      1  2020
# ...

# %%
df[df["Injury Location"].isnull()][["Date","Injury Location","Gender","Days Lost","Plant"]]
# Out:
#           Date Injury Location  Gender  Days Lost       Plant
# 1     3-Jan-20             NaN    Male        0.5     Alabama
# 5    11-Jan-20             NaN  Female        0.0     Georgia
# 8    15-Jan-20             NaN    Male        0.0     Florida
# 10   18-Jan-20             NaN  Female        0.0        Iowa
# 25   11-Feb-20             NaN    Male        0.0    Illinois
# 27   13-Feb-20             NaN    Male        4.5    Illinois
# 34   22-Feb-20             NaN    Male        0.0     Georgia
# 39    3-Mar-20             NaN    Male        2.5     Florida
# 53    6-Apr-20             NaN    Male        0.0    Illinois
# 55   12-Apr-20             NaN    Male        0.0        Ohio
# 83   17-May-20             NaN    Male        0.0        Ohio
# 111   6-Jul-20             NaN  Female        0.0        Ohio
# 118  13-Jul-20             NaN    Male        3.5        Ohio
# 124  26-Jul-20             NaN    Male        5.0       Texas
# ...

# %%
df[df["Injury Location"].isnull()]["Age Group"]
# Out:
# 1      35-49
# 5        50+
# 8      18-24
# 10     35-49
# 25     25-34
# 27       50+
# 34     25-34
# 39       50+
# 53     18-24
# 55     25-34
# 83     35-49
# 111      50+
# 118      50+
# 124    25-34
# 127      50+
# 129    35-49
# 152    25-34
# 163    35-49
# 169    25-34
# 170    35-49
# 173      50+
# 196    25-34
# 200    25-34
# 229    25-34
# 236      50+
# 259    25-34
# 273      50+
# 275      50+
# 283      50+
# 313      50+
# 349      50+
# 384      50+
# 405    25-34
# 421      50+
# 425    25-34
# 426    25-34
# 429    35-49
# 443    25-34
# 449      50+
# 469    25-34
# 487      50+
# 497    18-24
# Name: Age Group, dtype: object

# %%
df[(df["Shift"]=="Day") & (df["Gender"]=="Male")][["Date","Injury Location","Gender","Age Group"]]
# Out:
#           Date Injury Location Gender Age Group
# 1     3-Jan-20             NaN   Male     35-49
# 2     3-Jan-20             Eye   Male     18-24
# 4     7-Jan-20            Legs   Male     25-34
# 6    11-Jan-20            Neck   Male     25-34
# 12   26-Jan-20             Eye   Male     35-49
# ..         ...             ...    ...       ...
# 497  23-May-22             NaN   Male     18-24
# 503   3-Jun-22           Trunk   Male     18-24
# 505   5-Jun-22            Back   Male     25-34
# 506   7-Jun-22         Abdomen   Male     25-34
# 508  25-Jun-22            Feet   Male       50+
#
# [157 rows x 4 columns]

# %%
df
# Out:
#           Date Injury Location  Gender Age Group   Incident Type  Days Lost  \
# 0     1-Jan-20        Multiple    Male     25-34            Burn        0.0
# 1     3-Jan-20             NaN    Male     35-49         Vehicle        0.5
# 2     3-Jan-20             Eye    Male     18-24             Cut        0.0
# 3     4-Jan-20            Legs  Female       50+  Falling object        0.0
# 4     7-Jan-20            Legs    Male     25-34         Lifting        0.0
# ..         ...             ...     ...       ...             ...        ...
# 509  26-Jun-22            Head  Female     25-34   Crush & Pinch        0.0
# 510  27-Jun-22           Hands    Male     25-34         Lifting        0.0
# 511  28-Jun-22           Hands    Male     25-34             Cut        0.0
# 512  28-Jun-22           Trunk    Male       50+  Falling object        0.0
# 513  28-Jun-22           Hands    Male     18-24         Vehicle        0.0
#
# ...

# %%
df[(df["Injury Location"]=="Eye")]
# Out:
#           Date Injury Location  Gender Age Group   Incident Type  Days Lost  \
# 2     3-Jan-20             Eye    Male     18-24             Cut        0.0
# 12   26-Jan-20             Eye    Male     35-49         Vehicle        0.0
# 13   27-Jan-20             Eye    Male       50+            Burn        0.0
# 14   27-Jan-20             Eye    Male     35-49            Burn        0.0
# 38    3-Mar-20             Eye    Male     35-49            Burn        0.0
# 40    6-Mar-20             Eye    Male     25-34            Burn        0.0
# 46   20-Mar-20             Eye    Male     35-49         Lifting        0.0
# 56   13-Apr-20             Eye  Female       50+         Vehicle        4.5
# 61   16-Apr-20             Eye    Male       50+            Burn        0.0
# 69   25-Apr-20             Eye  Female       50+       Equipment        0.0
# 77    9-May-20             Eye    Male     35-49            Fall        0.0
# ...

# %%
df[(df["WkDay"]=="Sun")]
# Out:
#           Date Injury Location  Gender Age Group  Incident Type  Days Lost  \
# 7    12-Jan-20            Feet    Male     35-49           Burn        1.5
# 12   26-Jan-20             Eye    Male     35-49        Vehicle        0.0
# 21    9-Feb-20            Feet    Male     35-49  Crush & Pinch        0.0
# 22    9-Feb-20            Head    Male     25-34      Equipment        4.5
# 30   16-Feb-20         Abdomen    Male       50+      Slip/trip        0.0
# ..         ...             ...     ...       ...            ...        ...
# 484  24-Apr-22         Abdomen    Male     25-34  Crush & Pinch        0.0
# 485  24-Apr-22             Eye    Male     18-24      Slip/trip        0.0
# 492   8-May-22             Eye    Male     25-34      Slip/trip        0.0
# 505   5-Jun-22            Back    Male     25-34      Slip/trip        0.0
# 509  26-Jun-22            Head  Female     25-34  Crush & Pinch        0.0
#
# ...
